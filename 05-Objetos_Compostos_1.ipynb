# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Quais as vantagens da utilização de objetos compostos em detrimento dos objetos simples?

# %% [markdown]
# R: Os objetos compostos tem como principal vantagem permitir a organização do codigo, além de permitir o uso de varios objetos simples.

# %% [markdown]
# ## 02 – Instancie uma variável da classe tupla, contendo 5 valores de qualquer classe, e recupere os valores:

# %%
tupla_exercicio_aula5 = (1, 2, 3, 4, 5)
print(tupla_exercicio_aula5)
type(tupla_exercicio_aula5)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %% [markdown]
# ## 03 – Instancie uma variável da classe lista, contendo 5 valores de qualquer classe, e recupere cada um dos valores:

# %%
lista_exercicios_aula5 = [1, 2, 3, 4, 5]
print(lista_exercicios_aula5)
type(lista_exercicios_aula5)
# Out:
# [1, 2, 3, 4, 5]
# list

# %% [markdown]
# ## 04 – Instancie uma variável da classe lista, contendo 5 nomes de genes diferentes, recupere de cada um dos valores quantas letras ‘a’ estão presentes:

# %%
lista_genes = ['BRCA1', 'TP53', 'EGFR', 'CHEK2', 'PTEN']
print(lista_genes)
print(lista_genes[0].count('A'))
print(lista_genes[1].count('A'))
print(lista_genes[2].count('A'))
print(lista_genes[3].count('A'))
print(lista_genes[4].count('A'))
# Out:
# ['BRCA1', 'TP53', 'EGFR', 'CHEK2', 'PTEN']
# 1
# 0
# 0
# 0
# 0

# %% [markdown]
# ## 05 – Instancie uma variável da classe lista, contendo 5 valores, e recupere do segundo ao quarto valores:

# %%
lista_2 = [1, 2, 3, 4, 5]
print(lista_2)
print(lista_2[1:4])
# Out:
# [1, 2, 3, 4, 5]
# [2, 3, 4]

# %% [markdown]
# ## 06 – Instancie uma variável da classe string com o seu nome como valor, e recupere o segundo e o último valores:

# %%
nome = 'natalia'
print(nome)
print(nome[1])
print(nome[-1])
# Out:
# natalia
# a
# a

# %% [markdown]
# ## 07 – Instancie uma variável da classe dicionário com quantos valores inteiros desejar. Usando as funções globais, retorne a classe do objeto, quantos valores estão instanciados e a soma dos valores contidos no objeto:

# %%
dicionario_aula5 = {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
print(dicionario_aula5)
print(type(dicionario_aula5))
print(len(dicionario_aula5))
print(sum(dicionario_aula5.values()))
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
# <class 'dict'>
# 6
# 21

# %% [markdown]
# ## 08 – Instancie uma variável da classe dicionário. Os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes de genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser o número de caracteres em cada index. Retorne o objeto:

# %%
lista_genes = ['BRCA1', 'TP53', 'EGFR', 'CHEK2', 'PTEN']

dicionario = {
    lista_genes[0]: len(lista_genes[0]),
    lista_genes[1]: len(lista_genes[1]),
    lista_genes[2]: len(lista_genes[2]),
    lista_genes[3]: len(lista_genes[3]),
    lista_genes[4]: len(lista_genes[4])
}

print(dicionario)
# Out:
# {'BRCA1': 5, 'TP53': 4, 'EGFR': 4, 'CHEK2': 5, 'PTEN': 4}

# %% [markdown]
# ## 09 – Instancie cinco variáveis da classe lista. Cada uma delas será referente à um dos valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Em cada uma das listas, você deve inserir o número de caracteres presentes no nome do gene, os dois primeiros caracteres do nome, quantas vezes aparece o caractere ‘a’ e se no nome aparecem os caracteres ‘hu’. Para isso você deve utilizar a indexação de lista. Retorne cada um dos objetos:

# %%
lista_genes = ['BRCA1', 'TP53', 'EGFR', 'CHEK2', 'PTEN']
lista1 = [
    len(lista_genes[0]),
    lista_genes[0][:2],
    lista_genes[0].count('A'),
    'hu' in lista_genes[0]
]
print(lista1)

lista2 = [
    len(lista_genes[1]),
    lista_genes[1][:2],
    lista_genes[1].count('A'),
    'hu' in lista_genes[1]
]
print(lista2)

lista3 = [
    len(lista_genes[2]),
    lista_genes[2][:2],
    lista_genes[2].count('A'),
    'hu' in lista_genes[2]
]
print(lista3)

lista4 = [
    len(lista_genes[3]),
    lista_genes[3][:2],
    lista_genes[3].count('A'),
    'hu' in lista_genes[3]
]
print(lista4)

lista5 = [
    len(lista_genes[4]),
    lista_genes[4][:2],
    lista_genes[4].count('A'),
    'hu' in lista_genes[4]
]
print(lista5)
# Out:
# [5, 'BR', 1, False]
# [4, 'TP', 0, False]
# [4, 'EG', 0, False]
# [5, 'CH', 0, False]
# [4, 'PT', 0, False]

# %% [markdown]
# ## 10 – Instancie uma variável da classe dicionário, os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser as listas instanciadas no exercício 9. Retorne o objeto.

# %%
dicionario_genes = {
    lista_genes[0]: lista1,
    lista_genes[1]: lista2,
    lista_genes[2]: lista3, 
    lista_genes[3]: lista4,
    lista_genes[4]: lista5
}
print(dicionario_genes)
# Out:
# {'BRCA1': [5, 'BR', 1, False], 'TP53': [4, 'TP', 0, False], 'EGFR': [4, 'EG', 0, False], 'CHEK2': [5, 'CH', 0, False], 'PTEN': [4, 'PT', 0, False]}
